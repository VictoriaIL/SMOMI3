# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 uninstall tensorflow 
# !pip3 install tensorflow-gpu==1.14
# Out:
# Uninstalling tensorflow-2.2.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.2.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.2.0
# Collecting tensorflow-gpu==1.14
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 42kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.2)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/tensorflow-estimator/
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 2.8MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.34.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.0.8)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.18.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.9.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 12.6MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (3.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (1.29.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14) (0.3.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (46.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.2.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14) (3.1.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
# Successfully installed tensorboard-1.14.0 tensorflow-estimator-1.14.0 tensorflow-gpu-1.14.0

# %%
import os
os.chdir("/content/drive/My Drive/СМОМИ/Лаба 3")
# !ls
# Out:
#  images  'lab3(2)_3.ipynb'  'lab3(3).ipynb'   lab3.ipynb   logs   modelB.h5

# %%
import argparse
import glob
import numpy as np
import tensorflow as tf
import time
from tensorflow.python import keras as keras
from tensorflow.python.keras.callbacks import LearningRateScheduler

# %%
LOG_DIR = 'logs'
SHUFFLE_BUFFER = 10
BATCH_SIZE = 8
NUM_CLASSES = 2
PARALLEL_CALLS=4
RESIZE_TO = 224
TRAINSET_SIZE = 5216
VALSET_SIZE=624

# %%
def parse_proto_example(proto):
    keys_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/class/label': tf.FixedLenFeature([], tf.int64, default_value=tf.zeros([], dtype=tf.int64))
    }
    example = tf.parse_single_example(proto, keys_to_features)
    example['image'] = tf.image.decode_jpeg(example['image/encoded'], channels=3)
    example['image'] = tf.image.convert_image_dtype(example['image'], dtype=tf.float32)
    example['image'] = tf.image.resize_images(example['image'], tf.constant([RESIZE_TO, RESIZE_TO]))
    return example['image'], example['image/class/label']

    
def normalize(image, label):
    return tf.image.per_image_standardization(image), label


def resize(image, label):
    return tf.image.resize_images(image, tf.constant([RESIZE_TO, RESIZE_TO])), label
    
def create_dataset(filenames, batch_size):
    """Create dataset from tfrecords file
    :tfrecords_files: Mask to collect tfrecords file of dataset
    :returns: tf.data.Dataset
    """
    return tf.data.TFRecordDataset(filenames) \
        .map(parse_proto_example) \
        .map(resize) \
        .map(normalize) \
        .map(resize) \
        .shuffle(buffer_size=5 * batch_size) \
        .repeat() \
        .batch(batch_size) \
        .prefetch(2 * batch_size)

class Validation(tf.keras.callbacks.Callback):
    def __init__(self, log_dir, validation_files, batch_size):
        self.log_dir = log_dir
        self.validation_files = validation_files
        self.batch_size = batch_size

    def on_epoch_end(self, epoch, logs=None):
        print('The average loss for epoch {} is {:7.2f} '.format(
            epoch, logs['loss']
        ))

        validation_dataset = create_dataset(self.validation_files, self.batch_size)
        validation_images, validation_labels = validation_dataset.make_one_shot_iterator().get_next()
        validation_labels = tf.one_hot(validation_labels, NUM_CLASSES)

        result = self.model.evaluate(
            validation_images,
            validation_labels,
            steps=int(np.ceil(VALSET_SIZE / float(BATCH_SIZE)))
        )
        callback = tf.keras.callbacks.TensorBoard(log_dir=self.log_dir, update_freq='epoch', batch_size=self.batch_size)

        callback.set_model(self.model)
        callback.on_epoch_end(epoch, {
            'val_' + self.model.metrics_names[i]: v for i, v in enumerate(result)
        })

# %%
def build_model():
    model = keras.models.load_model('modelB.h5')
    model.trainable = True
    return model

# %%
train_path = './images/train*'
test_path = './images/test*'

# %%
def main():
    train_dataset = create_dataset(glob.glob(train_path), BATCH_SIZE)
    train_images, train_labels = train_dataset.make_one_shot_iterator().get_next()
    train_labels = tf.one_hot(train_labels, NUM_CLASSES)

    model = build_model()

    model.compile(
        optimizer=keras.optimizers.sgd(lr=0.00000000003, momentum=0.9),
        loss=tf.keras.losses.categorical_crossentropy,
        metrics=[tf.keras.metrics.categorical_accuracy],
        target_tensors=[train_labels]
    )

    log_dir='{}/xray-{}'.format(LOG_DIR, time.time())
    model.fit(
        (train_images, train_labels),
        epochs=100, 
        steps_per_epoch=int(np.ceil(TRAINSET_SIZE / float(BATCH_SIZE))),
        callbacks=[
            tf.keras.callbacks.TensorBoard(log_dir),
            Validation(log_dir, validation_files=glob.glob(test_path), batch_size=BATCH_SIZE)
        ]
    )
 


if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1514: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From <ipython-input-16-3a173e3754fa>:3: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0244 - categorical_accuracy: 0.3813The average loss for epoch 0 is    0.02
# 78/78 [==============================] - 21s 266ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1458
# 652/652 [==============================] - 229s 351ms/step - loss: 0.0244 - categorical_accuracy: 0.3808
# Epoch 2/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0240 - categorical_accuracy: 0.3821The average loss for epoch 1 is    0.02
# 78/78 [==============================] - 15s 189ms/step - loss: 0.1329 - categorical_accuracy: 0.4006
# 652/652 [==============================] - 213s 327ms/step - loss: 0.0240 - categorical_accuracy: 0.3819
# Epoch 3/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0235 - categorical_accuracy: 0.3817The average loss for epoch 2 is    0.02
# 78/78 [==============================] - 14s 178ms/step - loss: 0.2215 - categorical_accuracy: 0.5096
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0235 - categorical_accuracy: 0.3827
# Epoch 4/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0231 - categorical_accuracy: 0.3840The average loss for epoch 3 is    0.02
# 78/78 [==============================] - 13s 169ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1378
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0231 - categorical_accuracy: 0.3838
# Epoch 5/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0228 - categorical_accuracy: 0.3865The average loss for epoch 4 is    0.02
# 78/78 [==============================] - 13s 173ms/step - loss: 0.0109 - categorical_accuracy: 0.1458
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0228 - categorical_accuracy: 0.3863
# Epoch 6/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0224 - categorical_accuracy: 0.3881The average loss for epoch 5 is    0.02
# 78/78 [==============================] - 21s 263ms/step - loss: 0.4276 - categorical_accuracy: 0.8333
# 652/652 [==============================] - 219s 336ms/step - loss: 0.0225 - categorical_accuracy: 0.3884
# Epoch 7/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0220 - categorical_accuracy: 0.3875The average loss for epoch 6 is    0.02
# 78/78 [==============================] - 13s 172ms/step - loss: 0.1466 - categorical_accuracy: 0.3798
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0220 - categorical_accuracy: 0.3884
# Epoch 8/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0217 - categorical_accuracy: 0.3919The average loss for epoch 7 is    0.02
# 78/78 [==============================] - 13s 165ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1410
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0217 - categorical_accuracy: 0.3919
# Epoch 9/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0215 - categorical_accuracy: 0.3934The average loss for epoch 8 is    0.02
# 78/78 [==============================] - 13s 167ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1442
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0215 - categorical_accuracy: 0.3932
# Epoch 10/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0213 - categorical_accuracy: 0.3967The average loss for epoch 9 is    0.02
# 78/78 [==============================] - 14s 180ms/step - loss: 0.0039 - categorical_accuracy: 0.1522
# 652/652 [==============================] - 213s 327ms/step - loss: 0.0213 - categorical_accuracy: 0.3963
# Epoch 11/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0210 - categorical_accuracy: 0.3978The average loss for epoch 10 is    0.02
# 78/78 [==============================] - 16s 202ms/step - loss: 0.3626 - categorical_accuracy: 0.7292
# 652/652 [==============================] - 215s 329ms/step - loss: 0.0209 - categorical_accuracy: 0.3974
# Epoch 12/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0207 - categorical_accuracy: 0.4003The average loss for epoch 11 is    0.02
# 78/78 [==============================] - 13s 167ms/step - loss: 0.0014 - categorical_accuracy: 0.1554
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0207 - categorical_accuracy: 0.3999
# Epoch 13/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0206 - categorical_accuracy: 0.4017The average loss for epoch 12 is    0.02
# 78/78 [==============================] - 13s 172ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1554
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0206 - categorical_accuracy: 0.4013
# Epoch 14/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0205 - categorical_accuracy: 0.4032The average loss for epoch 13 is    0.02
# 78/78 [==============================] - 18s 233ms/step - loss: 0.2691 - categorical_accuracy: 0.5737
# 652/652 [==============================] - 217s 332ms/step - loss: 0.0204 - categorical_accuracy: 0.4032
# Epoch 15/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0199 - categorical_accuracy: 0.4050The average loss for epoch 14 is    0.02
# 78/78 [==============================] - 15s 188ms/step - loss: 0.3110 - categorical_accuracy: 0.6314
# 652/652 [==============================] - 216s 331ms/step - loss: 0.0200 - categorical_accuracy: 0.4059
# Epoch 16/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0200 - categorical_accuracy: 0.4103The average loss for epoch 15 is    0.02
# 78/78 [==============================] - 13s 169ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1619
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0200 - categorical_accuracy: 0.4105
# Epoch 17/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0199 - categorical_accuracy: 0.4113The average loss for epoch 16 is    0.02
# 78/78 [==============================] - 13s 169ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1619
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0198 - categorical_accuracy: 0.4110
# Epoch 18/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0197 - categorical_accuracy: 0.4142The average loss for epoch 17 is    0.02
# 78/78 [==============================] - 13s 171ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1667
# 652/652 [==============================] - 212s 325ms/step - loss: 0.0197 - categorical_accuracy: 0.4137
# Epoch 19/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0196 - categorical_accuracy: 0.4171The average loss for epoch 18 is    0.02
# 78/78 [==============================] - 17s 219ms/step - loss: 0.2624 - categorical_accuracy: 0.5705
# 652/652 [==============================] - 217s 332ms/step - loss: 0.0196 - categorical_accuracy: 0.4168
# Epoch 20/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0192 - categorical_accuracy: 0.4192The average loss for epoch 19 is    0.02
# 78/78 [==============================] - 14s 174ms/step - loss: 0.0941 - categorical_accuracy: 0.3381
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0193 - categorical_accuracy: 0.4201
# Epoch 21/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0193 - categorical_accuracy: 0.4230The average loss for epoch 20 is    0.02
# 78/78 [==============================] - 13s 173ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1731
# 652/652 [==============================] - 213s 326ms/step - loss: 0.0193 - categorical_accuracy: 0.4225
# Epoch 22/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0192 - categorical_accuracy: 0.4270The average loss for epoch 21 is    0.02
# 78/78 [==============================] - 15s 188ms/step - loss: 0.1132 - categorical_accuracy: 0.3622
# 652/652 [==============================] - 214s 328ms/step - loss: 0.0192 - categorical_accuracy: 0.4270
# Epoch 23/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0192 - categorical_accuracy: 0.4295The average loss for epoch 22 is    0.02
# 78/78 [==============================] - 20s 260ms/step - loss: 0.4462 - categorical_accuracy: 0.8109
# 652/652 [==============================] - 220s 337ms/step - loss: 0.0193 - categorical_accuracy: 0.4304
# Epoch 24/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0189 - categorical_accuracy: 0.4324The average loss for epoch 23 is    0.02
# 78/78 [==============================] - 13s 170ms/step - loss: 0.0214 - categorical_accuracy: 0.2228
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0190 - categorical_accuracy: 0.4329
# Epoch 25/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 0.4378The average loss for epoch 24 is    0.02
# 78/78 [==============================] - 13s 170ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1955
# 652/652 [==============================] - 212s 326ms/step - loss: 0.0188 - categorical_accuracy: 0.4373
# Epoch 26/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0188 - categorical_accuracy: 0.4430The average loss for epoch 25 is    0.02
# 78/78 [==============================] - 14s 175ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.1987
# 652/652 [==============================] - 213s 327ms/step - loss: 0.0187 - categorical_accuracy: 0.4429
# Epoch 27/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0187 - categorical_accuracy: 0.4464The average loss for epoch 26 is    0.02
# 78/78 [==============================] - 14s 182ms/step - loss: 0.1105 - categorical_accuracy: 0.3542
# 652/652 [==============================] - 214s 328ms/step - loss: 0.0186 - categorical_accuracy: 0.4459
# Epoch 28/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0186 - categorical_accuracy: 0.4501The average loss for epoch 27 is    0.02
# 78/78 [==============================] - 14s 183ms/step - loss: 0.2714 - categorical_accuracy: 0.5481
# 652/652 [==============================] - 214s 328ms/step - loss: 0.0186 - categorical_accuracy: 0.4509
# Epoch 29/100
# 651/652 [============================>.] - ETA: 0s - loss: 0.0185 - categorical_accuracy: 0.4553The average loss for epoch 28 is    0.02
# 78/78 [==============================] - 14s 173ms/step - loss: 0.0000e+00 - categorical_accuracy: 0.2131
# 652/652 [==============================] - 213s 326ms/step - loss: 0.0185 - categorical_accuracy: 0.4551
# Epoch 30/100
# 537/652 [=======================>......] - ETA: 35s - loss: 0.0219 - categorical_accuracy: 0.4914

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs
